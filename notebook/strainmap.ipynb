# %% [markdown]
# # Map of NBC Strains
# This notebook utilise folium to map where the strain was collected. Requires GPS coordinates.

# %%
# Load Library
import pandas as pd
import folium
from folium.features import DivIcon
from IPython.display import display, IFrame

# %%
# load metadata in ../data
df = pd.read_csv('../data/dyrehavn_metadata.csv', index_col=0)
df
# Out:
#            Sample Type              Location                   GPS  \
# Sample no.
# 24                Soil  Grassland, Dyrehaven  55.788800, 12.558300
# 25                Soil  Grassland, Dyrehaven  55.795200, 12.580600
# 26                Soil  Grassland, Dyrehaven  55.791200, 12.575100
#
#            additional name                   Description Collection Date  \
# Sample no.
# 24                      P5  grassland, non-acricultural       26-08-2018
# 25                      P8  grassland, non-acricultural       26-08-2018
# 26                      P9  grassland, non-acricultural       26-08-2018
#
#            Project Code Storage location (Builing, room, Freezer, Shelf, Box)  \
# Sample no.
# 24             PCem0003                             B221, R160, Freezer #?
# 25             PCem0003                             B221, R160, Freezer #?
# 26             PCem0003                             B221, R160, Freezer #?
#
# ...

# %%
# extract gps coordinates
gps = [[float(i.split(', ')[0]), float(i.split(', ')[1])] for i in df['GPS']]

# set sample names
name = [i for i in df['additional name']]

# set colors
color = ['red', 'green', 'blue']

# %%
# initiate map using a gps location as a starting point
m = folium.Map(location=gps[1], zoom_start=14, tiles="openstreetmap")

# fill in data points for the map
for num, i in enumerate(gps):
    # uses circles as sample points
    folium.Circle(
        i, popup="<i>"+name[num]+"</i>", radius=100, color=color[num], fill=True).add_to(m) # other description can be added later in popup, set size with radius
    # set sample name format
    folium.map.Marker(
        [i[0]+0.0005, i[1]+0.002], # modify this so that text does not collide with markets
        icon=DivIcon(
            icon_size=(150,36),
            icon_anchor=(0,0),
            html='<div style="font-size: 24pt">%s</div>' % name[num], # set font size as you like
            )
        ).add_to(m)
# save output as html    
m.save('../output/dyrehavn_map.html')

# show map
#m

# %%
# show map with IFrame
display(IFrame("../output/dyrehavn_map.html", width=1200, height=700))
# Out:
#         <iframe
#             width="1200"
#             height="700"
#             src="../output/dyrehavn_map.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# If map does not show, open the [html output.](../output/dyrehavn_map.html)
