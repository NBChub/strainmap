# %% [markdown]
# # Map of NBC Strains
# This notebook utilise folium to map where the strain was collected. Requires GPS coordinates.

# %%
# Load Library
import pandas as pd
import folium
from folium.features import DivIcon
#from IPython.display import display, IFrame
import re

# %%
# function to convert dms to dd
# https://stackoverflow.com/questions/33997361/how-to-convert-degree-minute-second-to-degree-decimal


def dms2dd(degrees, minutes, seconds, direction):
    dd = float(degrees) + float(minutes)/60 + float(seconds)/(60*60);
    if direction == 'E' or direction == 'N':
        dd *= -1
    return dd;

def dd2dms(deg):
    d = int(deg)
    md = abs(deg - d) * 60
    m = int(md)
    sd = (md - m) * 60
    return [d, m, sd]

def parse_dms(dms):
    parts = re.split('[^\d\w]+', dms)
    lat = dms2dd(parts[0], parts[1], parts[2], parts[3])

    return (lat)

# %%
# load data
df_nbc = pd.read_csv('../data/df_strains.csv')
df_nbc.head()
# Out:
#    Strain ID Soil sample name Country of origin  \
# 0  NBC 00001      Jernbanevej           Denmark
# 1  NBC 00002      Jernbanevej           Denmark
# 2  NBC 00003      Lyngby lake           Denmark
# 3  NBC 00005      Lyngby lake           Denmark
# 4  NBC 00006      Lyngby lake           Denmark
#
#                     Color of colony Colony morphology WT halo against AB?  \
# 0                             white           wrinkly                  No
# 1                             white           wrinkly         reduced ZOI
# 2                       white/brown           wrinkly                  No
# 3  black base, white aerial mycelia             bumpy                  No
# 4                       beige/cream           wrinkly                  No
#
#   WT halo against E. coli?  Frozen on: Sent through co-ALE? Sequenced?  ...  \
# 0                       No         NaN                  NaN        NaN  ...
# 1              reduzed ZOI         NaN                  Yes        Yes  ...
# 2                       No  10/17/2016                  NaN        Yes  ...
# 3                       No  10/17/2016                  NaN        Yes  ...
# 4                       No  10/17/2016                  Yes        NaN  ...
#
#   Bioactive cmpd identified? Comments     Strain  \
# 0                        NaN      NaN  NBC 00001
# 1                        NaN      NaN  NBC 00002
# 2                        NaN      NaN  NBC 00003
# 3                        NaN      NaN  NBC 00005
# 4                        NaN      NaN  NBC 00006
#
#                   Description of soil sample   Location  \
# 0  Backyard where Pep used to live in Lyngby     Lyngby
# 1  Backyard where Pep used to live in Lyngby     Lyngby
# 2                 Under a log near the water  Lyngby Sø
# 3                 Under a log near the water  Lyngby Sø
# 4                 Under a log near the water  Lyngby Sø
#
#                 GPS coordinates Date of collection   Collected by:  \
# 0   55 16' 18" N,  12 30' 4"  E         2016-07-25  Pep Charusanti
# 1   55 16' 18" N,  12 30' 4"  E         2016-07-25  Pep Charusanti
# 2  55 46' 24" N,  12 29' 34"  E         2016-07-25  Pep Charusanti
# 3  55 46' 24" N,  12 29' 34"  E         2016-07-25  Pep Charusanti
# 4  55 46' 24" N,  12 29' 34"  E         2016-07-25  Pep Charusanti
#
#   Media for Isolation Soil meta Comments
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 NaN                NaN
#
# [5 rows x 21 columns]

# %%
# cleaning gps data into dd format
data = []
for num, i in enumerate(df_nbc['GPS coordinates']):
    try:
        # split df
        parts = re.split('[^\d\w]+', i)
        #print(len(parts) == 4)
        
        # dd format
        if len(parts) == 4:
            gps = [float(str(parts[0])+'.'+str(parts[1])), 
                   float(str(parts[2])+'.'+str(parts[3])),
                  'dd']
            #print(gps)
        
        elif len(parts) == 6:
            gps = [float(str(parts[0])+'.'+str(parts[1])), 
                   float(str(parts[3])+'.'+str(parts[4])),
                  'dd']
            #print(gps, parts[2], parts[-1])
        # dmm
        
        elif len(parts) == 8:
            gps = [(str(parts[0])+'°'+str(parts[1])+"'"+str(parts[2])+" "+str(parts[3])),
                   (str(parts[4])+'°'+str(parts[5])+"'"+str(parts[6])+" "+str(parts[7])),
                  'dms']
        
        elif len(parts) == 10:
            gps = [(str(parts[0])+'°'+str(parts[1])+"'"+str(parts[2])+"."+str(parts[3])+" "+str(parts[4])),
                   (str(parts[5])+'°'+str(parts[6])+"'"+str(parts[7])+"."+str(parts[8])+" "+str(parts[9])),
                  'dms']
        
        elif len(parts) == 12:
            gps = [(str(parts[0])+'°'+str(parts[1])+"'"+str(parts[2])+" "+str(parts[3])),
                   (str(parts[4])+'°'+str(parts[5])+"'"+str(parts[6])+" "+str(parts[7])), 
                  'dms']
        
        else:
            i #print(len(gps[0]))
        #print(gps)
        if gps[2] == 'dms':
            gps[0] = parse_dms(gps[0])
            gps[1] = parse_dms(gps[1])
        #print(gps)
        
        data.append([num, gps[0], gps[1]])
        
    except TypeError:
        num, i
        
# add data to df
df_latlong = pd.DataFrame(data=data, columns=['index', 'lat', 'long']).set_index('index')
df_nbc = df_nbc.merge(df_latlong, left_index=True, right_index=True)
df_nbc.to_csv('../tables/df_cleaned.csv')

# %%
# drop data without GPS
df = df_nbc[df_nbc['lat'].notna()]
df

# notes that some of the coordinates in negative are wrong
# Out:
#       Strain ID Soil sample name Country of origin  \
# 0     NBC 00001      Jernbanevej           Denmark
# 1     NBC 00002      Jernbanevej           Denmark
# 2     NBC 00003      Lyngby lake           Denmark
# 3     NBC 00005      Lyngby lake           Denmark
# 4     NBC 00006      Lyngby lake           Denmark
# ...         ...              ...               ...
# 1565  NBC 01571  Stenbjerg marsh           Denmark
# 1566  NBC 01572  Stenbjerg marsh           Denmark
# 1567  NBC 01573  Stenbjerg marsh           Denmark
# 1568  NBC 01574  Stenbjerg marsh           Denmark
# 1569  NBC 01575  Stenbjerg marsh           Denmark
#
#                        Color of colony Colony morphology WT halo against AB?  \
# 0                                white           wrinkly                  No
# 1                                white           wrinkly         reduced ZOI
# 2                          white/brown           wrinkly                  No
# 3     black base, white aerial mycelia             bumpy                  No
# 4                          beige/cream           wrinkly                  No
# ...                                ...               ...                 ...
# 1565                               NaN               NaN                 NaN
# 1566                               NaN               NaN                 NaN
# 1567                               NaN               NaN                 NaN
# 1568                               NaN               NaN                 NaN
# 1569                               NaN               NaN                 NaN
#
#      WT halo against E. coli?  Frozen on: Sent through co-ALE? Sequenced?  \
# 0                          No         NaN                  NaN        NaN
# 1                 reduzed ZOI         NaN                  Yes        Yes
# 2                          No  10/17/2016                  NaN        Yes
# 3                          No  10/17/2016                  NaN        Yes
# 4                          No  10/17/2016                  Yes        NaN
# ...                       ...         ...                  ...        ...
# 1565                      NaN         NaN                  NaN        NaN
# 1566                      NaN         NaN                  NaN        NaN
# 1567                      NaN         NaN                  NaN        NaN
# 1568                      NaN         NaN                  NaN        NaN
# 1569                      NaN         NaN                  NaN        NaN
#
#       ...     Strain                 Description of soil sample   Location  \
# 0     ...  NBC 00001  Backyard where Pep used to live in Lyngby     Lyngby
# 1     ...  NBC 00002  Backyard where Pep used to live in Lyngby     Lyngby
# 2     ...  NBC 00003                 Under a log near the water  Lyngby Sø
# 3     ...  NBC 00005                 Under a log near the water  Lyngby Sø
# 4     ...  NBC 00006                 Under a log near the water  Lyngby Sø
# ...   ...        ...                                        ...        ...
# 1565  ...  NBC 01571                                      marsh  Stenbjerg
# 1566  ...  NBC 01572                                      marsh  Stenbjerg
# 1567  ...  NBC 01573                                      marsh  Stenbjerg
# 1568  ...  NBC 01574                                      marsh  Stenbjerg
# 1569  ...  NBC 01575                                      marsh  Stenbjerg
#
#                    GPS coordinates Date of collection   Collected by:  \
# 0      55 16' 18" N,  12 30' 4"  E         2016-07-25  Pep Charusanti
# 1      55 16' 18" N,  12 30' 4"  E         2016-07-25  Pep Charusanti
# 2     55 46' 24" N,  12 29' 34"  E         2016-07-25  Pep Charusanti
# 3     55 46' 24" N,  12 29' 34"  E         2016-07-25  Pep Charusanti
# 4     55 46' 24" N,  12 29' 34"  E         2016-07-25  Pep Charusanti
# ...                            ...                ...             ...
# 1565      56°54'49.2"N 8°22'51.6"E         2021-03-06   Julie Nielsen
# 1566      56°54'49.2"N 8°22'51.6"E         2021-03-06   Julie Nielsen
# 1567      56°54'49.2"N 8°22'51.6"E         2021-03-06   Julie Nielsen
# 1568      56°54'49.2"N 8°22'51.6"E         2021-03-06   Julie Nielsen
# 1569      56°54'49.2"N 8°22'51.6"E         2021-03-06   Julie Nielsen
#
#      Media for Isolation Soil meta Comments        lat       long
# 0                    NaN                NaN -55.271667 -12.501111
# 1                    NaN                NaN -55.271667 -12.501111
# 2                    NaN                NaN -55.773333 -12.492778
# 3                    NaN                NaN -55.773333 -12.492778
# 4                    NaN                NaN -55.773333 -12.492778
# ...                  ...                ...        ...        ...
# 1565                 NaN                NaN  56.913611   8.380833
# 1566                 NaN                NaN  56.913611   8.380833
# 1567                 NaN                NaN  56.913611   8.380833
# 1568                 NaN                NaN  56.913611   8.380833
# 1569                 NaN                NaN  56.913611   8.380833
#
# [748 rows x 23 columns]

# %%
# initiate map using a gps location as a starting point
m = folium.Map(location=[55.47166666666667, 10.654444444444445], zoom_start=8, tiles="openstreetmap")

# fill in data points for the map
for num, i in enumerate(data): # need to use the df rather than the raw coordinates
    # uses circles as sample points
    folium.Circle(
        i[1:], popup="<i>needtofillwithsamplenames</i>", radius=2500, color='red', fill=True).add_to(m) # other description can be added later in popup, set size with radius
# save output as html    
m.save('../output/strainmap.html')

# show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1845b6475a2c4463a0f04aabfa869c63%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1845b6475a2c4463a0f04aabfa869c63%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1845b6475a2c4463a0f04aabfa869c63%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1845b6475a2c4463a0f04aabfa869c63%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B55.47166666666667%2C%2010.654444444444445%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...
